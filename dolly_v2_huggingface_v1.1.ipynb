# %%
# !pip -q install git+https://github.com/huggingface/transformers # need to install from github
# !pip -q install accelerate>=0.12.0
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 72.1 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done

# %%
import torch
from transformers import pipeline

# use dolly-v2-12b if you're using Colab Pro+, using pythia-2.8b for Free Colab
generate_text = pipeline(model="databricks/dolly-v2-2-8b", 
                         torch_dtype=torch.bfloat16, 
                         trust_remote_code=True,
                         device_map="auto")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/820 [00:00<?, ?B/s]
# Downloading (…)instruct_pipeline.py:   0%|          | 0.00/7.15k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/5.68G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/450 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/228 [00:00<?, ?B/s]

# %%
generate_text("Explain to me the difference between nuclear fission and fusion.")
# Out:
# "Nuclear fission releases a single atomic nuclei into an atom's nuclear fissionables, the short-lived stable isotopes of hydrogen which comprise most of the atom's atomic mass, including the four hydrogen isotopes that are components of deuterium and tritium. Nuclear fusion is a physical process which occurs when two or more atomic nuclei come close enough together to exchange electrons and form a higher atomic mass atomic nuclei called a fusion product. The term nuclear fission includes both nuclear fission and neutron fission, which is the reaction in which a neutron absorbs a proton and becomes a neutron. Both processes release nuclear isotopes. The neutron chain reaction, in which one neutron captures a proton to become a neutron and another absorbs a neutron from another atom, releases both neutrons and protons as nuclear isotopes."

# %%
generate_text("Explain self-attention and transformer to me like I'm 5 years old (ELI5).")
# Out:
# 'Self-attention is one of the key building blocks in transformer. The idea is that we can take many layers of self-attention and apply it element-wise. This is because a single vector will be able to attend to every single other vector in the graph. For example, when we\'re looking at the vector a, self-attention will be able to attend to the other vector b, because a is "attending" to b, in the vector a, via the mechanism of self-attention. The transformer architecture draws inspiration from this idea. Self-attention is also one of the most time-consuming computations, so it is often applied in the shallow layer of a network. For example, some form of self-attention may be applied to the query, key, and values in a3.\n\nIn another way of looking at it, a shallow feed-forward network can be seen as a special kind of transformer that uses only one layer of self-attention.'
